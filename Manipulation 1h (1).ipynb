# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 22
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['text.color'] = 'k'
import matplotlib.pyplot as plt
#warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('MiningProcess_Flotation_Plant_Database2.csv')
df.shape
# Out:
# (4097, 24)

# %%
df
# Out:
#                      date  % Iron Feed  % Silica Feed  Starch Flow  \
# 0     2017-03-10 01:00:00        55.20          16.98  3162.625026
# 1     2017-03-10 02:00:00        55.20          16.98  3133.256389
# 2     2017-03-10 03:00:00        55.20          16.98  3479.482944
# 3     2017-03-10 04:00:00        55.20          16.98  3228.036436
# 4     2017-03-10 05:00:00        55.20          16.98  3327.280739
# ...                   ...          ...            ...          ...
# 4092  2017-09-09 19:00:00        49.75          23.20  3327.047776
# 4093  2017-09-09 20:00:00        49.75          23.20  4225.800333
# 4094  2017-09-09 21:00:00        49.75          23.20  2808.214692
# 4095  2017-09-09 22:00:00        49.75          23.20  3191.497672
# 4096  2017-09-09 23:00:00        49.75          23.20  3638.543653
#
#       Amina Flow  Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 0     578.786678     398.753368    10.113487          1.729558
# ...

# %%
df.describe()
# Out:
#        % Iron Feed  % Silica Feed  Starch Flow   Amina Flow  Ore Pulp Flow  \
# count  4097.000000    4097.000000  4097.000000  4097.000000    4097.000000
# mean     56.294730      14.651733  2869.142009   488.145318     397.578386
# std       5.158347       6.808236   950.480080    83.689937       8.370683
# min      42.740000       1.310000    54.595483   242.927477     376.837604
# 25%      52.670000       8.940000  2168.968993   436.037967     398.851356
# 50%      56.080000      13.850000  2908.340847   502.454283     399.842656
# 75%      59.720000      19.600000  3528.727412   549.522256     400.589883
# max      65.780000      33.400000  6270.158798   736.982378     418.070232
#
#        Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# count  4097.000000       4097.000000                   4097.000000
# mean      9.767642          1.680380                    280.151579
# std       0.378027          0.063775                     29.410048
# ...

# %%
df[['% Iron Concentrate','% Silica Concentrate']].mean().plot(kind='bar');

# %%
df.plot(y=['% Iron Concentrate'], x='date', figsize=(20, 10),fontsize=15);
plt.ylabel('% Iron Concentrate',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, '% Iron Concentrate')

# %%
df.plot(y=['% Silica Concentrate'], x='date', figsize=(20, 10),fontsize=15);
plt.ylabel('% Silica Concentrate',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, '% Silica Concentrate')

# %%
plt.figure(figsize=(30, 25))
p = sns.heatmap(df.corr(), annot=True)

# %%
df.plot(y=['Starch Flow'], x='date', figsize=(20, 10),fontsize=15);
plt.ylabel('Starch Flow',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Starch Flow')

# %%
df.plot(y=['Amina Flow'], x='date', figsize=(20, 10),fontsize=15);
plt.ylabel('Amina Flow',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Amina Flow')

# %%
fig, axes = plt.subplots(nrows=5, ncols=1)
 # Or equivalently,  "plt.tight_layout()"


df.plot(y=['Amina Flow'], ax=axes[0], x='date', figsize=(50, 10)); 
df.plot(y=['Starch Flow'],ax=axes[1], x='date',figsize=(50,10)); 
df.plot(y=['Ore Pulp Flow'],ax=axes[2], x='date',figsize=(50,10));
df.plot(y=['Ore Pulp pH'],ax=axes[3], x='date',figsize=(50,10));
df.plot(y=['Ore Pulp Density'],ax=axes[4], x='date',figsize=(50,10));
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# ...

# %%
fig, axes = plt.subplots(nrows=7, ncols=1)
 # Or equivalently,  "plt.tight_layout()"


df.plot(y=['Flotation Column 01 Air Flow'], ax=axes[0], x='date', figsize=(50, 10)); 
df.plot(y=['Flotation Column 02 Air Flow'],ax=axes[1], x='date',figsize=(50,10)); 
df.plot(y=['Flotation Column 03 Air Flow'],ax=axes[2], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 04 Air Flow'],ax=axes[3], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 05 Air Flow'],ax=axes[4], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 06 Air Flow'],ax=axes[5], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 07 Air Flow'],ax=axes[6], x='date',figsize=(50,10));
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# ...

# %%
fig, axes = plt.subplots(nrows=7, ncols=1)
 # Or equivalently,  "plt.tight_layout()"


df.plot(y=['Flotation Column 01 Level'], ax=axes[0], x='date', figsize=(50, 10)); 
df.plot(y=['Flotation Column 02 Level'],ax=axes[1], x='date',figsize=(50,10)); 
df.plot(y=['Flotation Column 03 Level'],ax=axes[2], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 04 Level'],ax=axes[3], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 05 Level'],ax=axes[4], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 06 Level'],ax=axes[5], x='date',figsize=(50,10));
df.plot(y=['Flotation Column 07 Level'],ax=axes[6], x='date',figsize=(50,10));
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# ...
