# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 22
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# using the date as an index

# %%
df = pd.read_csv('C:/Users/moham/Desktop/MiningProcess_Flotation_Plant_Database_seconds.csv', decimal=',')
#df.set_index('date', inplace=True)
#df = df.drop(['index'], axis=1)
#df.rename(columns={"index1": "date"}, inplace = True)

# %%
df.set_index('date', inplace=True)

# %%
df.shape
# Out:
# (737453, 23)

# %%
df.columns= [ '% Iron Feed', '% Silica Feed','Starch Flow','Amina Flow','Ore Pulp Flow','Ore Pulp pH','Ore Pulp Density','p-Flotation Column 01 Air Flow','p-Flotation Column 02 Air Flow','p-Flotation Column 03 Air Flow','p-Flotation Column 04 Air Flow','p-Flotation Column 05 Air Flow','p-Flotation Column 06 Air Flow','p-Flotation Column 07 Air Flow','p-Flotation Column 01 Level','p-Flotation Column 02 Level','p-Flotation Column 03 Level','p-Flotation Column 04 Level','p-Flotation Column 05 Level','p-Flotation Column 06 Level','p-Flotation Column 07 Level','otp2_% Iron Concentrate','% Silica Concentrate']

# %%
df.head()
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# date
# 2017-03-10 01:00:00        395.713      10.0664              1.74
# 2017-03-10 01:00:00        397.383      10.0672              1.74
# 2017-03-10 01:00:00        399.668      10.0680              1.74
# 2017-03-10 01:00:00        397.939      10.0689              1.74
# 2017-03-10 01:00:00        400.254      10.0697              1.74
#
#                      p-Flotation Column 01 Air Flow  \
# date
# 2017-03-10 01:00:00                         249.214
# 2017-03-10 01:00:00                         249.719
# 2017-03-10 01:00:00                         249.741
# 2017-03-10 01:00:00                         249.917
# 2017-03-10 01:00:00                         250.203
#
#                      p-Flotation Column 02 Air Flow  \
# date
# 2017-03-10 01:00:00                         253.235
# 2017-03-10 01:00:00                         250.532
# 2017-03-10 01:00:00                         247.874
# 2017-03-10 01:00:00                         254.487
# 2017-03-10 01:00:00                         252.136
#
#                      p-Flotation Column 03 Air Flow  ...  \
# date                                                 ...
# 2017-03-10 01:00:00                         250.576  ...
# 2017-03-10 01:00:00                         250.862  ...
# 2017-03-10 01:00:00                         250.313  ...
# 2017-03-10 01:00:00                         250.049  ...
# 2017-03-10 01:00:00                         249.895  ...
#
#                      p-Flotation Column 07 Air Flow  \
# date
# 2017-03-10 01:00:00                         250.884
# 2017-03-10 01:00:00                         248.994
# 2017-03-10 01:00:00                         248.071
# 2017-03-10 01:00:00                         251.147
# 2017-03-10 01:00:00                         248.928
#
#                      p-Flotation Column 01 Level  p-Flotation Column 02 Level  \
# date
# 2017-03-10 01:00:00                      457.396                      432.962
# 2017-03-10 01:00:00                      451.891                      429.560
# 2017-03-10 01:00:00                      451.240                      468.927
# 2017-03-10 01:00:00                      452.441                      458.165
# 2017-03-10 01:00:00                      452.441                      452.900
#
#                      p-Flotation Column 03 Level  p-Flotation Column 04 Level  \
# date
# 2017-03-10 01:00:00                      424.954                      443.558
# 2017-03-10 01:00:00                      432.939                      448.086
# 2017-03-10 01:00:00                      434.610                      449.688
# 2017-03-10 01:00:00                      442.865                      446.210
# 2017-03-10 01:00:00                      450.523                      453.670
#
#                      p-Flotation Column 05 Level  p-Flotation Column 06 Level  \
# date
# 2017-03-10 01:00:00                      502.255                      446.370
# 2017-03-10 01:00:00                      496.363                      445.922
# 2017-03-10 01:00:00                      484.411                      447.826
# 2017-03-10 01:00:00                      471.411                      437.690
# 2017-03-10 01:00:00                      462.598                      443.682
#
#                      p-Flotation Column 07 Level  otp2_% Iron Concentrate  \
# date
# 2017-03-10 01:00:00                      523.344                    66.91
# 2017-03-10 01:00:00                      498.075                    66.91
# 2017-03-10 01:00:00                      458.567                    66.91
# 2017-03-10 01:00:00                      427.669                    66.91
# 2017-03-10 01:00:00                      425.679                    66.91
#
#                      % Silica Concentrate
# date
# 2017-03-10 01:00:00                  1.31
# 2017-03-10 01:00:00                  1.31
# 2017-03-10 01:00:00                  1.31
# 2017-03-10 01:00:00                  1.31
# 2017-03-10 01:00:00                  1.31
#
# [5 rows x 23 columns]

# %% [markdown]
# ploting every output and input

# %%
df.plot(y=['% Iron Feed'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('% Iron Feed',fontsize=20)
# Out:
# Text(0, 0.5, '% Iron Feed')

# %%
df.plot(y=['% Silica Feed'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('% Silica feed',fontsize=20)
# Out:
# Text(0, 0.5, '% Silica feed')

# %%
df.plot(y=['Starch Flow'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Starch Flow',fontsize=20)
# Out:
# Text(0, 0.5, 'Starch Flow')

# %%
df.plot(y=['Amina Flow'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Amina Flow',fontsize=20)
# Out:
# Text(0, 0.5, 'Amina Flow')

# %%
df.plot(y=['Ore Pulp Flow'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Ore Pulp Flow',fontsize=20)
# Out:
# Text(0, 0.5, 'Ore Pulp Flow')

# %%
df.plot(y=['Ore Pulp pH'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Ore Pulp pH',fontsize=20)
# Out:
# Text(0, 0.5, 'Ore Pulp pH')

# %%
df.plot(y=['Ore Pulp Density'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Ore Pulp Density',fontsize=20)
# Out:
# Text(0, 0.5, 'Ore Pulp Density')

# %%
fig,axes = plt.subplots(nrows=7, ncols=1)
 # Or equivalently,  "plt.tight_layout()"


df.plot(y=['p-Flotation Column 01 Air Flow'], ax=axes[0],  figsize=(50, 10)); 
df.plot(y=['p-Flotation Column 02 Air Flow'],ax=axes[1],figsize=(50,10)); 
df.plot(y=['p-Flotation Column 03 Air Flow'],ax=axes[2], figsize=(50,10));
df.plot(y=['p-Flotation Column 04 Air Flow'],ax=axes[3],figsize=(50,10));
df.plot(y=['p-Flotation Column 05 Air Flow'],ax=axes[4], figsize=(50,10));
df.plot(y=['p-Flotation Column 06 Air Flow'],ax=axes[5], figsize=(50,10));
df.plot(y=['p-Flotation Column 07 Air Flow'],ax=axes[6],figsize=(50,10));
# Out:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %%
fig, axes = plt.subplots(nrows=7, ncols=1)
 # Or equivalently,  "plt.tight_layout()"


df.plot(y=['p-Flotation Column 01 Level'], ax=axes[0],  figsize=(50, 10)); 
df.plot(y=['p-Flotation Column 02 Level'],ax=axes[1],figsize=(50,10)); 
df.plot(y=['p-Flotation Column 03 Level'],ax=axes[2], figsize=(50,10));
df.plot(y=['p-Flotation Column 04 Level'],ax=axes[3], figsize=(50,10));
df.plot(y=['p-Flotation Column 05 Level'],ax=axes[4], figsize=(50,10));
df.plot(y=['p-Flotation Column 06 Level'],ax=axes[5], figsize=(50,10));
df.plot(y=['p-Flotation Column 07 Level'],ax=axes[6], figsize=(50,10));
# Out:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\users\moham\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %%
df.plot(y=['% Silica Concentrate'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('% Silica Concentrate',fontsize=20)
# Out:
# Text(0, 0.5, '% Silica Concentrate')

# %% [markdown]
# The correlation matrix

# %%
plt.figure(figsize=(30, 25))
p = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# We can see that the % of iron and silica concentrate are highly correlated, so it'll be enough to just predict the % of silica and we'll take out the % of iron

# %%
df = df.drop(['otp2_% Iron Concentrate'], axis=1)

# %%
df.head(1)
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# date
# 2017-03-10 01:00:00        395.713      10.0664              1.74
#
#                      p-Flotation Column 01 Air Flow  \
# date
# 2017-03-10 01:00:00                         249.214
#
#                      p-Flotation Column 02 Air Flow  \
# date
# 2017-03-10 01:00:00                         253.235
#
#                      p-Flotation Column 03 Air Flow  ...  \
# date                                                 ...
# 2017-03-10 01:00:00                         250.576  ...
#
#                      p-Flotation Column 06 Air Flow  \
# date
# 2017-03-10 01:00:00                         250.225
#
#                      p-Flotation Column 07 Air Flow  \
# date
# 2017-03-10 01:00:00                         250.884
#
#                      p-Flotation Column 01 Level  p-Flotation Column 02 Level  \
# date
# 2017-03-10 01:00:00                      457.396                      432.962
#
#                      p-Flotation Column 03 Level  p-Flotation Column 04 Level  \
# date
# 2017-03-10 01:00:00                      424.954                      443.558
#
#                      p-Flotation Column 05 Level  p-Flotation Column 06 Level  \
# date
# 2017-03-10 01:00:00                      502.255                       446.37
#
#                      p-Flotation Column 07 Level  % Silica Concentrate
# date
# 2017-03-10 01:00:00                      523.344                  1.31
#
# [1 rows x 22 columns]

# %%
Y = df['% Silica Concentrate']
X = df.drop(['% Silica Concentrate'], axis=1)

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
X_scaled = pd.DataFrame(min_max_scaler.fit_transform(X), columns=X.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
_ = reg.fit(X_train, Y_train)

# %%
predictions = reg.predict(X_test)
predictions
# Out:
# array([2.79425373, 2.40803132, 2.34064178, ..., 3.04508587, 1.6966514 ,
#        1.76263937])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
error = mean_squared_error(Y_test, predictions)
error
# Out:
# 1.0700528622420211

# %%
Rsquar = r2_score(Y_test, predictions)
Rsquar
# Out:
# 0.15332053266921475

# %%
from sklearn.tree import DecisionTreeRegressor
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_2.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
Y_2 = regr_2.predict(X_test)

# %%
Y_2
# Out:
# array([2.86090876, 2.81251276, 2.81251276, ..., 2.86090876, 1.83628698,
#        1.83628698])

# %%
error2 = mean_squared_error(Y_test, Y_2)
error2
# Out:
# 0.9762405877784242

# %%
Rsquar = r2_score(Y_test, predictions)
Rsquar
# Out:
# 0.15332053266921475

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=20, random_state=42)
regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)

# %%
Y_pred

# %%
error3 = mean_squared_error(Y_test, Y_pred)
error3

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))

# %%
Rsquar = r2_score(Y_test, Y_pred)
Rsquar

# %%
from sklearn.ensemble import GradientBoostingRegressor
reg1 = GradientBoostingRegressor()
reg1.fit(X_train, Y_train)
Y_gradient_boosting_pred = reg1.predict(X_test)
Y_gradient_boosting_pred

# %%
Rsquar2 = r2_score(Y_test, Y_gradient_boosting_pred)
Rsquar2

# %%
from sklearn.ensemble import ExtraTreesRegressor
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, Y_train)
Y_pred3 = reg.predict(X_test)
Y_pred3

# %%
Rsquar3 = r2_score(Y_test, Y_pred3)
Rsquar3

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=42)
xgb_model.fit(X_train, Y_train)
Y_xgb_pred = xgb_model.predict(X_test)
Y_xgb_pred

# %%
Rsquar3 = r2_score(Y_test, Y_xgb_pred)
Rsquar3

# %%
embed_dim = 128
lstm_out = 200
batch_size = 32

model = Sequential()
model.add(Embedding(2500, embed_dim,input_length = X.shape[1], dropout = 0.2))
model.add(LSTM(lstm_out, dropout_U = 0.2, dropout_W = 0.2))
model.add(Dense(2,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())

# %%
model.fit(X_train, Y_train, batch_size =batch_size, nb_epoch = 1,  verbose = 5)

# %%
score,acc = model.evaluate(x_test,y_test,verbose=2,batch_size=batch_size)
print("score:%.2f "%(score))
print("Validation Accuracy:%.2f "%(acc))
