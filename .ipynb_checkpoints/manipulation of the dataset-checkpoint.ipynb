# %% [markdown]
# Date                             :        date of the measurement

# %% [markdown]
# % Iron Feed : % of Iron that comes from the iron ore that is being fed into the flotation cells

# %% [markdown]
# % Silica Feed                    :        % of silica (impurity) that comes from the iron ore that is being fed into the flotation cells

# %% [markdown]
# Starch Flow                      :        Starch (reagent) Flow measured in m3/h

# %% [markdown]
# Amina Flow                       :        Amina (reagent) Flow measured in m3/h

# %% [markdown]
# Ore Pulp Flow                    :        t/h

# %% [markdown]
# Ore Pulp pH                      :        pH scale from 0 to 14

# %% [markdown]
# Ore Pulp Density                 :        Density scale from 1 to 3 kg/cm³

# %% [markdown]
# Flotation Column 01..07 Air Flow     :        Air flow that goes into the flotation cell measured in Nm³/h

# %% [markdown]
# Flotation Column 01..07 Level        :        Froth level in the flotation cell measured in mm (millimeters)

# %% [markdown]
# %Iron Concentrate                :        % of Iron which represents how much iron is presented in the
#                                        end of the flotation process (0-100%, lab measurement)

# %% [markdown]
# % Silica Concentrate             :        % of silica which represents how much iron is presented in the end
#                                        of the flotation process (0-100%, lab measurement)

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:/Users/moham/Desktop/MiningProcess_Flotation_Plant_Database.csv', decimal=',')
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#                  date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0 2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1 2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2 2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3 2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4 2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df.columns= ['date', '% Iron Feed', '% Silica Feed','Starch Flow','Amina Flow','Ore Pulp Flow','Ore Pulp pH','Ore Pulp Density','p-Flotation Column 01 Air Flow','p-Flotation Column 02 Air Flow','p-Flotation Column 03 Air Flow','p-Flotation Column 04 Air Flow','p-Flotation Column 05 Air Flow','p-Flotation Column 06 Air Flow','p-Flotation Column 07 Air Flow','p-Flotation Column 01 Level','p-Flotation Column 02 Level','p-Flotation Column 03 Level','p-Flotation Column 04 Level','p-Flotation Column 05 Level','p-Flotation Column 06 Level','p-Flotation Column 07 Level','otp2_% Iron Concentrate','% Silica Concentrate']

# %%
df
# Out:
#                       date  % Iron Feed  % Silica Feed  Starch Flow  \
# 0      2017-03-10 01:00:00        55.20          16.98      3019.53
# 1      2017-03-10 01:00:00        55.20          16.98      3024.41
# 2      2017-03-10 01:00:00        55.20          16.98      3043.46
# 3      2017-03-10 01:00:00        55.20          16.98      3047.36
# 4      2017-03-10 01:00:00        55.20          16.98      3033.69
# ...                    ...          ...            ...          ...
# 737448 2017-09-09 23:00:00        49.75          23.20      2710.94
# 737449 2017-09-09 23:00:00        49.75          23.20      2692.01
# 737450 2017-09-09 23:00:00        49.75          23.20      2692.20
# 737451 2017-09-09 23:00:00        49.75          23.20      1164.12
# 737452 2017-09-09 23:00:00        49.75          23.20      1164.12
#
#         Amina Flow  Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 0          557.434        395.713     10.06640           1.74000
# 1          563.965        397.383     10.06720           1.74000
# 2          568.054        399.668     10.06800           1.74000
# 3          568.665        397.939     10.06890           1.74000
# 4          558.167        400.254     10.06970           1.74000
# ...            ...            ...          ...               ...
# 737448     441.052        386.570      9.62129           1.65365
# 737449     473.436        384.939      9.62063           1.65352
# 737450     500.488        383.496      9.61874           1.65338
# 737451     491.548        384.976      9.61686           1.65324
# 737452     468.019        384.801      9.61497           1.65310
#
#         p-Flotation Column 01 Air Flow  p-Flotation Column 02 Air Flow  ...  \
# 0                              249.214                         253.235  ...
# 1                              249.719                         250.532  ...
# 2                              249.741                         247.874  ...
# 3                              249.917                         254.487  ...
# 4                              250.203                         252.136  ...
# ...                                ...                             ...  ...
# 737448                         302.344                         298.786  ...
# 737449                         303.013                         301.879  ...
# 737450                         303.662                         307.397  ...
# 737451                         302.550                         301.959  ...
# 737452                         300.355                         292.865  ...
#
#         p-Flotation Column 07 Air Flow  p-Flotation Column 01 Level  \
# 0                              250.884                      457.396
# 1                              248.994                      451.891
# 2                              248.071                      451.240
# 3                              251.147                      452.441
# 4                              248.928                      452.441
# ...                                ...                          ...
# 737448                         313.695                      392.160
# 737449                         236.700                      401.505
# 737450                         225.879                      408.899
# 737451                         308.115                      405.107
# 737452                         308.115                      413.754
#
#         p-Flotation Column 02 Level  p-Flotation Column 03 Level  \
# 0                           432.962                      424.954
# 1                           429.560                      432.939
# 2                           468.927                      434.610
# 3                           458.165                      442.865
# 4                           452.900                      450.523
# ...                             ...                          ...
# 737448                      430.702                      872.008
# 737449                      404.616                      864.409
# 737450                      399.316                      867.598
# 737451                      466.832                      876.591
# 737452                      514.143                      881.323
#
#         p-Flotation Column 04 Level  p-Flotation Column 05 Level  \
# 0                           443.558                      502.255
# 1                           448.086                      496.363
# 2                           449.688                      484.411
# 3                           446.210                      471.411
# 4                           453.670                      462.598
# ...                             ...                          ...
# 737448                      418.725                      497.548
# 737449                      418.377                      506.398
# 737450                      419.531                      503.414
# 737451                      407.299                      502.301
# 737452                      378.969                      500.100
#
#         p-Flotation Column 06 Level  p-Flotation Column 07 Level  \
# 0                           446.370                      523.344
# 1                           445.922                      498.075
# 2                           447.826                      458.567
# 3                           437.690                      427.669
# 4                           443.682                      425.679
# ...                             ...                          ...
# 737448                      446.357                      416.892
# 737449                      372.995                      426.337
# 737450                      336.035                      433.130
# 737451                      340.844                      433.966
# 737452                      374.354                      441.182
#
#         otp2_% Iron Concentrate  otp1_% Silica Concentrate
# 0                         66.91                       1.31
# 1                         66.91                       1.31
# 2                         66.91                       1.31
# 3                         66.91                       1.31
# 4                         66.91                       1.31
# ...                         ...                        ...
# 737448                    64.27                       1.71
# 737449                    64.27                       1.71
# 737450                    64.27                       1.71
# 737451                    64.27                       1.71
# 737452                    64.27                       1.71
#
# [737453 rows x 24 columns]

# %% [markdown]
# We will create 2 datasets, one which will contain the data for every hour, and one for every 20 seconds

# %% [markdown]
# aggregation of the data for every hour instead of 20 seconds

# %%
df.groupby(['date']).mean().to_csv('MiningProcess_Flotation_Plant_Database_hour.csv')

# %% [markdown]
# creating the 20 second frequency Datetime Index.

# %%
hours = pd.Series(df['date'].unique())
hours.index = hours
len(hours)
# Out:
# 4097

# %%
date_range = pd.date_range(start=df.iloc[0,0], end='2017-09-09 23:59:40', freq='20S')

# %%
hours_list = hours.index.format()
print(hours_list[:5])
seconds_list = date_range.format()
print(seconds_list[:5])
# Out:
# ['2017-03-10 01:00:00', '2017-03-10 02:00:00', '2017-03-10 03:00:00', '2017-03-10 04:00:00', '2017-03-10 05:00:00']
# ['2017-03-10 01:00:00', '2017-03-10 01:00:20', '2017-03-10 01:00:40', '2017-03-10 01:01:00', '2017-03-10 01:01:20']

# %%
new_index = []
for idx in seconds_list:
    if (idx[:13] + ':00:00') in hours_list:
        new_index.append(idx)

# %%
print(len(new_index))
print(len(df))
# Out:
# 737460
# 737453

# %% [markdown]
# 7 missing datas.

# %% [markdown]
# Trying to find those 7 missing values

# %% [markdown]
# Show the hours with less than 180 records
# Missing data within the hour: 3600 / 20  = 180 (a sample is taken every 20 second for every hour) .

# %%
counts = df.groupby('date').count()
counts[counts['% Iron Feed'] < 180]
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-10 01:00:00          174            174          174         174
# 2017-04-10 00:00:00          179            179          179         179
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# date
# 2017-03-10 01:00:00            174          174               174
# 2017-04-10 00:00:00            179          179               179
#
#                      Flotation Column 01 Air Flow  \
# date
# 2017-03-10 01:00:00                           174
# 2017-04-10 00:00:00                           179
#
#                      Flotation Column 02 Air Flow  \
# date
# 2017-03-10 01:00:00                           174
# 2017-04-10 00:00:00                           179
#
#                      Flotation Column 03 Air Flow  ...  \
# date                                               ...
# 2017-03-10 01:00:00                           174  ...
# 2017-04-10 00:00:00                           179  ...
#
#                      Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# date
# 2017-03-10 01:00:00                           174                        174
# 2017-04-10 00:00:00                           179                        179
#
#                      Flotation Column 02 Level  Flotation Column 03 Level  \
# date
# 2017-03-10 01:00:00                        174                        174
# 2017-04-10 00:00:00                        179                        179
#
#                      Flotation Column 04 Level  Flotation Column 05 Level  \
# date
# 2017-03-10 01:00:00                        174                        174
# 2017-04-10 00:00:00                        179                        179
#
#                      Flotation Column 06 Level  Flotation Column 07 Level  \
# date
# 2017-03-10 01:00:00                        174                        174
# 2017-04-10 00:00:00                        179                        179
#
#                      % Iron Concentrate  % Silica Concentrate
# date
# 2017-03-10 01:00:00                 174                   174
# 2017-04-10 00:00:00                 179                   179
#
# [2 rows x 23 columns]

# %% [markdown]
# The first hour is missing 6 datas while the other one is missing one, to match the amount of records found for those hours we will remove the couple 20 seconds intervals.

# %%
date_range = date_range[6:]
date_range[:3]
hours_list = hours.index.format()
seconds_list = date_range.format()

# %% [markdown]
# The 6 missing values of the first hour has been taken out, now we will remove the whole interval of the last missing value (2017-04-10 00:00:00)

# %%
new_index = []
for idx in seconds_list:
    if (idx[:13] + ':00:00') in hours_list:
        new_index.append(idx)

new_index.remove('2017-04-10 00:00:00')

# %%
print(len(new_index))
print(len(df))
# Out:
# 737453
# 737453

# %%
df['index'] = new_index
df['index'] = pd.to_datetime(df['index'])
df.index = df['index']
df = df.loc[:, df.columns[:-1]]
df = df.drop(['date'], axis=1)
df.head()
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# index
# 2017-03-10 01:02:00         55.2          16.98      3019.53     557.434
# 2017-03-10 01:02:20         55.2          16.98      3024.41     563.965
# 2017-03-10 01:02:40         55.2          16.98      3043.46     568.054
# 2017-03-10 01:03:00         55.2          16.98      3047.36     568.665
# 2017-03-10 01:03:20         55.2          16.98      3033.69     558.167
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# index
# 2017-03-10 01:02:00        395.713      10.0664              1.74
# 2017-03-10 01:02:20        397.383      10.0672              1.74
# 2017-03-10 01:02:40        399.668      10.0680              1.74
# 2017-03-10 01:03:00        397.939      10.0689              1.74
# 2017-03-10 01:03:20        400.254      10.0697              1.74
#
#                      Flotation Column 01 Air Flow  \
# index
# 2017-03-10 01:02:00                       249.214
# 2017-03-10 01:02:20                       249.719
# 2017-03-10 01:02:40                       249.741
# 2017-03-10 01:03:00                       249.917
# 2017-03-10 01:03:20                       250.203
#
#                      Flotation Column 02 Air Flow  \
# index
# 2017-03-10 01:02:00                       253.235
# 2017-03-10 01:02:20                       250.532
# 2017-03-10 01:02:40                       247.874
# 2017-03-10 01:03:00                       254.487
# 2017-03-10 01:03:20                       252.136
#
#                      Flotation Column 03 Air Flow  ...  \
# index                                              ...
# 2017-03-10 01:02:00                       250.576  ...
# 2017-03-10 01:02:20                       250.862  ...
# 2017-03-10 01:02:40                       250.313  ...
# 2017-03-10 01:03:00                       250.049  ...
# 2017-03-10 01:03:20                       249.895  ...
#
#                      Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# index
# 2017-03-10 01:02:00                       250.884                    457.396
# 2017-03-10 01:02:20                       248.994                    451.891
# 2017-03-10 01:02:40                       248.071                    451.240
# 2017-03-10 01:03:00                       251.147                    452.441
# 2017-03-10 01:03:20                       248.928                    452.441
#
#                      Flotation Column 02 Level  Flotation Column 03 Level  \
# index
# 2017-03-10 01:02:00                    432.962                    424.954
# 2017-03-10 01:02:20                    429.560                    432.939
# 2017-03-10 01:02:40                    468.927                    434.610
# 2017-03-10 01:03:00                    458.165                    442.865
# 2017-03-10 01:03:20                    452.900                    450.523
#
#                      Flotation Column 04 Level  Flotation Column 05 Level  \
# index
# 2017-03-10 01:02:00                    443.558                    502.255
# 2017-03-10 01:02:20                    448.086                    496.363
# 2017-03-10 01:02:40                    449.688                    484.411
# 2017-03-10 01:03:00                    446.210                    471.411
# 2017-03-10 01:03:20                    453.670                    462.598
#
#                      Flotation Column 06 Level  Flotation Column 07 Level  \
# index
# 2017-03-10 01:02:00                    446.370                    523.344
# 2017-03-10 01:02:20                    445.922                    498.075
# 2017-03-10 01:02:40                    447.826                    458.567
# 2017-03-10 01:03:00                    437.690                    427.669
# 2017-03-10 01:03:20                    443.682                    425.679
#
#                      % Iron Concentrate  % Silica Concentrate
# index
# 2017-03-10 01:02:00               66.91                  1.31
# 2017-03-10 01:02:20               66.91                  1.31
# 2017-03-10 01:02:40               66.91                  1.31
# 2017-03-10 01:03:00               66.91                  1.31
# 2017-03-10 01:03:20               66.91                  1.31
#
# [5 rows x 23 columns]

# %%
df['index1'] = df.index

# %%
df.to_csv('MiningProcess_Flotation_Plant_Database_seconds.csv')

# %%
df1= pd.read_csv('C:/Users/moham/Documents/Github/Quality-prediction-in-a-mining-process/MiningProcess_Flotation_Plant_Database_hour.csv', decimal=',')

# %%
y=df['% Silica Concentrate']
X=df.drop('% Silica Concentrate',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
print("\nX_train:\n")
print(X_train.head())
print(X_train.shape)

print("\nX_test:\n")
print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#
#                       date  % Iron Feed  % Silica Feed  Starch Flow  \
# 96970  2017-04-14 17:00:00        53.91          18.19      2308.52
# 462122 2017-07-08 06:00:00        57.38          10.58      4541.63
# 432202 2017-07-01 08:00:00        56.70          13.98      3494.46
# 324673 2017-06-06 10:00:00        64.03           6.26      2983.11
# 369486 2017-06-16 19:00:00        61.32           6.08      3003.28
#
#         Amina Flow  Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 96970      496.191        405.291      9.47883           1.73562
# 462122     438.628        399.031      9.81241           1.67986
# 432202     533.527        402.870      9.98716           1.71811
# 324673     585.872        402.215     10.09140           1.71507
# 369486     403.775        399.664      9.64261           1.62456
#
#         p-Flotation Column 01 Air Flow  p-Flotation Column 02 Air Flow  ...  \
# 96970                          249.705                         250.413  ...
# 462122                         300.770                         307.813  ...
# 432202                         301.331                         299.260  ...
# 324673                         300.149                         251.405  ...
# 369486                         301.225                         299.491  ...
#
#         p-Flotation Column 06 Air Flow  p-Flotation Column 07 Air Flow  \
# 96970                          251.560                         251.005
# 462122                         291.185                         306.043
# 432202                         306.286                         302.804
# 324673                         305.472                         298.304
# 369486                         300.806                         298.389
#
#         p-Flotation Column 01 Level  p-Flotation Column 02 Level  \
# 96970                       600.282                      597.898
# 462122                      507.130                      467.040
# 432202                      505.255                      462.733
# 324673                      405.008                      451.340
# 369486                      388.382                      415.075
#
#         p-Flotation Column 03 Level  p-Flotation Column 04 Level  \
# 96970                       596.765                      438.869
# 462122                      499.114                      453.326
# 432202                      471.163                      482.121
# 324673                      400.364                      324.920
# 369486                      392.843                      412.075
#
#         p-Flotation Column 05 Level  p-Flotation Column 06 Level  \
# 96970                       396.806                      346.585
# 462122                      513.090                      467.906
# 432202                      489.310                      467.307
# 324673                      355.224                      334.324
# 369486                      400.113                      409.909
#
#         p-Flotation Column 07 Level  otp2_% Iron Concentrate
# 96970                       428.708                    65.64
# 462122                      448.147                    66.10
# 432202                      524.884                    65.03
# 324673                      416.783                    63.97
# 369486                      370.828                    65.73
#
# [5 rows x 23 columns]
# (589962, 23)
#
# X_test:
#
#                       date  % Iron Feed  % Silica Feed  Starch Flow  \
# 602527 2017-08-09 18:00:00        48.81          25.31   491.311000
# 82825  2017-04-11 11:00:00        56.57          13.47   461.043829
# 558492 2017-07-30 13:00:00        57.46          10.80  1475.440000
# 125404 2017-04-21 07:00:00        55.17          14.35  2238.630000
# 454194 2017-07-06 10:00:00        47.79          27.08   592.828338
#
#         Amina Flow  Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 602527  391.995000     381.794273      9.54102          1.650400
# 82825   281.752160     380.798601      9.14351          1.526152
# 558492  564.508000     401.977000      9.58372          1.688940
# 125404  486.480000     396.819000      9.67139          1.656740
# 454194  266.073053     397.667528     10.16160          1.524227
#
#         p-Flotation Column 01 Air Flow  p-Flotation Column 02 Air Flow  ...  \
# 602527                      299.594000                      303.094000  ...
# 82825                       330.500192                      185.447000  ...
# 558492                      302.462000                      256.167000  ...
# 125404                      250.269000                      249.359000  ...
# 454194                      176.030961                      186.031332  ...
#
#         p-Flotation Column 06 Air Flow  p-Flotation Column 07 Air Flow  \
# 602527                         294.337                         302.188
# 82825                          250.878                         285.638
# 558492                         295.657                         298.887
# 125404                         250.101                         254.800
# 454194                         199.717                         296.982
#
#         p-Flotation Column 01 Level  p-Flotation Column 02 Level  \
# 602527                   494.898000                   490.190000
# 82825                    848.295504                   804.232536
# 558492                   385.546000                   432.083000
# 125404                   619.870000                   586.876000
# 454194                   822.737314                   814.441677
#
#         p-Flotation Column 03 Level  p-Flotation Column 04 Level  \
# 602527                   614.193000                   344.789000
# 82825                    871.278346                   578.618860
# 558492                   373.137000                   313.430000
# 125404                   597.562000                   217.518000
# 454194                   870.542805                   623.762684
#
#         p-Flotation Column 05 Level  p-Flotation Column 06 Level  \
# 602527                   351.693000                   356.743000
# 82825                    654.168583                   507.303298
# 558492                   384.126000                   411.581000
# 125404                   391.159000                   387.643000
# 454194                   661.094665                   614.620414
#
#         p-Flotation Column 07 Level  otp2_% Iron Concentrate
# 602527                   360.688000                    65.04
# 82825                    630.620867                    65.28
# 558492                   415.871000                    64.88
# 125404                   365.422000                    62.45
# 454194                   635.166836                    64.18
#
# [5 rows x 23 columns]
# (147491, 23)
