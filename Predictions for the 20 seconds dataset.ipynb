# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 22
matplotlib.rcParams['ytick.labelsize'] = 20
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# using the date as an index

# %%
df = pd.read_csv('MiningProcess_Flotation_Plant_Database_seconds.csv')
df = df.drop(['index'], axis=1)
df.rename(columns={"index1": "date"}, inplace = True)

# %%
df.set_index('date', inplace=True)

# %%
df.head()
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-10 01:02:00         55.2          16.98      3019.53     557.434
# 2017-03-10 01:02:20         55.2          16.98      3024.41     563.965
# 2017-03-10 01:02:40         55.2          16.98      3043.46     568.054
# 2017-03-10 01:03:00         55.2          16.98      3047.36     568.665
# 2017-03-10 01:03:20         55.2          16.98      3033.69     558.167
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# date
# 2017-03-10 01:02:00        395.713      10.0664              1.74
# 2017-03-10 01:02:20        397.383      10.0672              1.74
# 2017-03-10 01:02:40        399.668      10.0680              1.74
# 2017-03-10 01:03:00        397.939      10.0689              1.74
# 2017-03-10 01:03:20        400.254      10.0697              1.74
#
#                      Flotation Column 01 Air Flow  \
# date
# 2017-03-10 01:02:00                       249.214
# ...

# %% [markdown]
# ploting every output and input

# %%
df.plot(y=['% Iron Feed'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('% Iron Feed',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, '% Iron Feed')

# %%
df.plot(y=['% Silica Feed'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('% Silica feed',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, '% Silica feed')

# %%
df.plot(y=['Starch Flow'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Starch Flow',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Starch Flow')

# %%
df.plot(y=['Amina Flow'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Amina Flow',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Amina Flow')

# %%
df.plot(y=['Ore Pulp Flow'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Ore Pulp Flow',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Ore Pulp Flow')

# %%
df.plot(y=['Ore Pulp pH'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Ore Pulp pH',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Ore Pulp pH')

# %%
df.plot(y=['Ore Pulp Density'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('Ore Pulp Density',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, 'Ore Pulp Density')

# %%
fig,axes = plt.subplots(nrows=7, ncols=1)
 # Or equivalently,  "plt.tight_layout()"


df.plot(y=['Flotation Column 01 Air Flow'], ax=axes[0],  figsize=(50, 10)); 
df.plot(y=['Flotation Column 02 Air Flow'],ax=axes[1],figsize=(50,10)); 
df.plot(y=['Flotation Column 03 Air Flow'],ax=axes[2], figsize=(50,10));
df.plot(y=['Flotation Column 04 Air Flow'],ax=axes[3],figsize=(50,10));
df.plot(y=['Flotation Column 05 Air Flow'],ax=axes[4], figsize=(50,10));
df.plot(y=['Flotation Column 06 Air Flow'],ax=axes[5], figsize=(50,10));
df.plot(y=['Flotation Column 07 Air Flow'],ax=axes[6],figsize=(50,10));
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# ...

# %%
fig, axes = plt.subplots(nrows=7, ncols=1)
 # Or equivalently,  "plt.tight_layout()"


df.plot(y=['Flotation Column 01 Level'], ax=axes[0],  figsize=(50, 10)); 
df.plot(y=['Flotation Column 02 Level'],ax=axes[1],figsize=(50,10)); 
df.plot(y=['Flotation Column 03 Level'],ax=axes[2], figsize=(50,10));
df.plot(y=['Flotation Column 04 Level'],ax=axes[3], figsize=(50,10));
df.plot(y=['Flotation Column 05 Level'],ax=axes[4], figsize=(50,10));
df.plot(y=['Flotation Column 06 Level'],ax=axes[5], figsize=(50,10));
df.plot(y=['Flotation Column 07 Level'],ax=axes[6], figsize=(50,10));
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# ...

# %%
df.plot(y=['% Silica Concentrate'], figsize=(30, 10),fontsize=10, use_index=True);
plt.ylabel('% Silica Concentrate',fontsize=20)
# Out:
# C:\Users\Achraf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0, 0.5, '% Silica Concentrate')

# %% [markdown]
# The correlation matrix

# %%
plt.figure(figsize=(30, 25))
p = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# We can see that the % of iron and silica concentrate are highly correlated, so it'll be enough to just predict the % of silica and we'll take out the % of iron

# %%
df = df.drop(['% Iron Concentrate'], axis=1)

# %%
df.head(1)
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-10 01:02:00         55.2          16.98      3019.53     557.434
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# date
# 2017-03-10 01:02:00        395.713      10.0664              1.74
#
#                      Flotation Column 01 Air Flow  \
# date
# 2017-03-10 01:02:00                       249.214
#
#                      Flotation Column 02 Air Flow  \
# date
# 2017-03-10 01:02:00                       253.235
#
#                      Flotation Column 03 Air Flow  ...  \
# date                                               ...
# 2017-03-10 01:02:00                       250.576  ...
#
#                      Flotation Column 06 Air Flow  \
# date
# 2017-03-10 01:02:00                       250.225
#
#                      Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# date
# ...
